# %%
MASK64 = (1 << 64) - 1
print(MASK64)
print(2**64 - 1)
print(1<<0)
print(1<<2) # 2^2
# Out:
# 18446744073709551615
# 18446744073709551615
# 1
# 4

# %%
x = 2**32 - 1
print(x & 0xFFFFFFFF)
# Out:
# 4294967295

# %%
x = 2**100
print(x)
print(int(x))

print(type(x))
# Out:
# 1267650600228229401496703205376
# 1267650600228229401496703205376
# <class 'int'>
